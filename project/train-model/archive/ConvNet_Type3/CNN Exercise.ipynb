# %% [markdown]
# ## Convolutional Networks
#
# We'll check out how to build a **convolutional network** to classify CIFAR10 images. By using weight sharing - multiple units with the same weights - convolutional layers are able to learn repeated patterns in your data. For example, a unit could learn the pattern for an eye, or a face, or lower level features like edges.

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

import torch
from torch import optim, nn
import torch.nn.functional as F

# %matplotlib inline 
import matplotlib.pyplot as plt

from torchsummary import summary  # install with 'pip install torchsummary'
from tensorboardX import SummaryWriter

from models import ConvNet_Type3 as ConvNet
ConvNet_Type = 3
from utils import plot_images, get_train_valid_loader, plot_weights, plot_gradient_flow

# %%
# get data loaders
trainloader, valloader = get_train_valid_loader()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# init net
net = ConvNet()

# plot net parameters
summary(net, input_size=(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 48, 32, 32]           3,648
#          MaxPool2d-2           [-1, 48, 16, 16]               0
#             Conv2d-3           [-1, 36, 16, 16]          15,588
#          MaxPool2d-4             [-1, 36, 8, 8]               0
#             Linear-5                  [-1, 288]         663,840
#             Linear-6                   [-1, 10]           2,890
# ================================================================
# Total params: 685,966
# Trainable params: 685,966
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.56
# Params size (MB): 2.62
# Estimated Total Size (MB): 3.19
# ----------------------------------------------------------------

# %%
# visualize init weights
w = net.conv1.weight.data.numpy()
plot_weights(w,scaling=True)

# %%
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
learning_rate = 1e-3
decayRate = 0.1
l2_reg = 0.01
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=learning_rate, weight_decay=l2_reg)

# https://discuss.pytorch.org/t/how-to-do-exponential-learning-rate-decay-in-pytorch/63146/3
# https://pytorch.org/docs/stable/optim.html#torch.optim.lr_scheduler.ReduceLROnPlateau
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, factor=decayRate, patience=3, threshold=1e-2, verbose = True)


epochs = 30
running_loss = 0
print_every = 200
training_steps = 0

# init tensorboard writer
writer = SummaryWriter()

val_acc_best = 0

for e in range(epochs):
    
    print('\n--- EPOCH %03d / %03d STARTED ---' % (e+1, epochs))
 
    # set net to train mode
    net.train()
    
    # log current learning rate
    writer.add_scalar('optimizer/learning_rate', optimizer.param_groups[0]['lr'], e+1)
    
    # train over all batches
    start = time.time()
    for idx_batch, (images, labels) in enumerate(trainloader):
        
        training_steps += 1
        
        if idx_batch % print_every == 0:
            print('---> train on batch %03d' % idx_batch)
        
        optimizer.zero_grad()
        output = net(images)
        loss = criterion(output, labels)
        loss.backward()
        
        optimizer.step()
        
        writer.add_scalar('train/loss_training_step', loss.item(), training_steps)
        
    # visualize gradients   
    plot_gradient_flow(net.named_parameters())

    # set net to evaluation mode
    net.eval()
    
    # evaluate on training data 
    train_loss_accum = 0.
    count_total = 0
    count_correct = 0
    for idx_batch, (images, labels) in enumerate(trainloader):
        output = net(images)
        loss = criterion(output, labels)
        train_loss_accum += loss.item()
        
        prediction = torch.argmax(F.softmax(output), axis=1)
        count_total += prediction.size(0)
        count_correct += (prediction == labels).sum().item()
        
    train_loss_avg = train_loss_accum / (idx_batch+1)
    train_acc = count_correct / count_total
    writer.add_scalar('train/loss_epoch', train_loss_avg, e+1)
    writer.add_scalar('train/accuracy', train_acc, e+1)
    
    # evaluate on validation data 
    val_loss_accum = 0.
    count_total = 0
    count_correct = 0
    for idx_batch, (images, labels) in enumerate(valloader):
        output = net(images)
        loss = criterion(output, labels)
        val_loss_accum += loss.item()
        
        prediction = torch.argmax(F.softmax(output), axis=1)
        count_total += prediction.size(0)
        count_correct += (prediction == labels).sum().item()

    val_loss_avg = val_loss_accum / (idx_batch+1)
    val_acc = count_correct / count_total
    writer.add_scalar('val/loss_epoch', val_loss_avg, e+1)
    writer.add_scalar('val/accuracy', val_acc, e+1)
    
    print('\nMetrics: ')
    print('---> train loss / accuracy: %.03f / %.03f' % (train_loss_avg, train_acc))
    print('---> val loss / accuracy:   %.03f / %.03f' % (val_loss_avg, val_acc))
    
    scheduler.step(val_loss_avg)
    
    print('filters conv1')
    w1 = net.conv1.weight.data.numpy()
    plot_weights(w1, scaling=True)
    plt.show()
    
    if val_acc > val_acc_best:
        val_acc_best = val_acc
        print('---> save new best checkpoint')
        torch.save(net.state_dict(), 'model_type-%d_epoch-%d_train-%.03f_val-%.03f.ckpt' % (ConvNet_Type,e+1,train_acc,val_acc))

# close tensorboard logging
writer.close()
# Out:
# --- EPOCH 001 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
# /home/ftm/.virtualenvs/epfl_dlav_gpu/lib/python3.5/site-packages/ipykernel_launcher.py:70: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# /home/ftm/.virtualenvs/epfl_dlav_gpu/lib/python3.5/site-packages/ipykernel_launcher.py:88: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Metrics:
# ---> train loss / accuracy: 1.225 / 0.567
# ---> val loss / accuracy:   1.223 / 0.571
# filters conv1
# ---> save new best checkpoint
#
# --- EPOCH 002 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 1.062 / 0.621
# ---> val loss / accuracy:   1.126 / 0.596
# filters conv1
# ---> save new best checkpoint
#
# --- EPOCH 003 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.983 / 0.659
# ---> val loss / accuracy:   1.048 / 0.642
# filters conv1
# ---> save new best checkpoint
#
# --- EPOCH 004 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.938 / 0.671
# ---> val loss / accuracy:   0.967 / 0.661
# filters conv1
# ---> save new best checkpoint
#
# --- EPOCH 005 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.921 / 0.672
# ---> val loss / accuracy:   0.955 / 0.638
# filters conv1
# --- EPOCH 006 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.921 / 0.675
# ---> val loss / accuracy:   0.938 / 0.652
# filters conv1
# --- EPOCH 007 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.874 / 0.695
# ---> val loss / accuracy:   0.918 / 0.678
# filters conv1
# ---> save new best checkpoint
#
# --- EPOCH 008 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.855 / 0.707
# ---> val loss / accuracy:   0.892 / 0.663
# filters conv1
# --- EPOCH 009 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.808 / 0.722
# ---> val loss / accuracy:   0.859 / 0.684
# filters conv1
# /home/ftm/Desktop/DLAV/lab3_theodor_husefest_simon_janssen/utils.py:161: RuntimeWarning: invalid value encountered in true_divide
#   img /= np.max(img)
# ---> save new best checkpoint
#
# --- EPOCH 010 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.783 / 0.733
# ---> val loss / accuracy:   0.824 / 0.693
# filters conv1
# ---> save new best checkpoint
#
# --- EPOCH 011 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.828 / 0.712
# ---> val loss / accuracy:   0.866 / 0.673
# filters conv1
# --- EPOCH 012 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.829 / 0.716
# ---> val loss / accuracy:   0.863 / 0.693
# filters conv1
# /home/ftm/Desktop/DLAV/lab3_theodor_husefest_simon_janssen/utils.py:145: RuntimeWarning: invalid value encountered in true_divide
#   img /= np.max(img)
# --- EPOCH 013 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.811 / 0.720
# ---> val loss / accuracy:   0.856 / 0.697
# filters conv1
# ---> save new best checkpoint
#
# --- EPOCH 014 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.786 / 0.729
# ---> val loss / accuracy:   0.825 / 0.694
# Epoch    14: reducing learning rate of group 0 to 1.0000e-04.
# filters conv1
# --- EPOCH 015 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.690 / 0.766
# ---> val loss / accuracy:   0.744 / 0.725
# filters conv1
# ---> save new best checkpoint
#
# --- EPOCH 016 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.677 / 0.772
# ---> val loss / accuracy:   0.749 / 0.722
# filters conv1
# --- EPOCH 017 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.669 / 0.774
# ---> val loss / accuracy:   0.735 / 0.724
# filters conv1
# --- EPOCH 018 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.660 / 0.779
# ---> val loss / accuracy:   0.731 / 0.735
# filters conv1
# ---> save new best checkpoint
#
# --- EPOCH 019 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.655 / 0.780
# ---> val loss / accuracy:   0.726 / 0.736
# filters conv1
# ---> save new best checkpoint
#
# --- EPOCH 020 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.647 / 0.782
# ---> val loss / accuracy:   0.719 / 0.738
# filters conv1
# ---> save new best checkpoint
#
# --- EPOCH 021 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.643 / 0.782
# ---> val loss / accuracy:   0.721 / 0.738
# filters conv1
# --- EPOCH 022 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.634 / 0.788
# ---> val loss / accuracy:   0.702 / 0.746
# filters conv1
# ---> save new best checkpoint
#
# --- EPOCH 023 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.626 / 0.791
# ---> val loss / accuracy:   0.700 / 0.740
# filters conv1
# --- EPOCH 024 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.626 / 0.788
# ---> val loss / accuracy:   0.706 / 0.744
# filters conv1
# --- EPOCH 025 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.612 / 0.795
# ---> val loss / accuracy:   0.700 / 0.739
# filters conv1
# --- EPOCH 026 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.621 / 0.790
# ---> val loss / accuracy:   0.712 / 0.736
# Epoch    26: reducing learning rate of group 0 to 1.0000e-05.
# filters conv1
# --- EPOCH 027 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.599 / 0.800
# ---> val loss / accuracy:   0.688 / 0.745
# filters conv1
# --- EPOCH 028 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.597 / 0.801
# ---> val loss / accuracy:   0.681 / 0.743
# filters conv1
# --- EPOCH 029 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.596 / 0.801
# ---> val loss / accuracy:   0.687 / 0.749
# filters conv1
# ---> save new best checkpoint
#
# --- EPOCH 030 / 030 STARTED ---
# ---> train on batch 000
# ---> train on batch 200
# ---> train on batch 400
# ---> train on batch 600
#
# Metrics:
# ---> train loss / accuracy: 0.596 / 0.801
# ---> val loss / accuracy:   0.683 / 0.738
# filters conv1

# %% [markdown]
# Save best trained model.
